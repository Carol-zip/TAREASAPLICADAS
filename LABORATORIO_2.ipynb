# %% [markdown]
# <a href="https://colab.research.google.com/github/Carol-zip/TAREASAPLICADAS/blob/main/LABORATORIO_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Integrantes 🐱
#
# **Stefania Coy Gomez**
#
# **Carol Daniela Muñoz Diaz**
#
# **Angie Michell Arevalo Sanchez**

# %% [markdown]
# <font color="ADFF2F">EJERCICIOS OPTIMIZACIÓN</font>
# 1. Encuentre las dimensiones del cilindro circular recto de volumen
# máximo que puede inscribirse en un cono circular recto dado
#
# semejanza de triángulos en el cono:
#
# $ \frac{H - h}{r} = \frac{H}{R} \implies h = H\left(1 - \frac{r}{R}\right)$
#
# sustituir h en v
#
# $\begin{align*}
# V(r) &= \pi r^2 \left[ H\left(1-\frac{r}{R}\right)\right] \\
#      &= \pi H\left(r^2 - \frac{r^3}{R}\right)
# \end{align*}$
#
# Derivar y igualar a cero
#
# $\frac{dV}{dr} = \pi H\left( 2r - \frac{3r^2}{R} \right) = 0 \implies 2r = \frac{3r^2}{R} \implies r = \frac{2R}{3}$
#
# Encontrar h
#
# $\begin{align*}
# h &= H\left(1 - \frac{2R/3}{R}\right) \\
#   &= \frac{H}{3}
# \end{align*}$
#
# Las dimensiones son: $r = \frac{2R}{3} h= \frac{H}{3}$
#
# 2. Suponga que un pez nada río arriba con velocidad relativa al agua
# $v$ y que la corriente del río tiene velocidad $-v_c$ (el signo negativo indica que la velocidad de la corriente es en dirección opuesta a la del pez). La energía empleada en recorrer una distancia $d$ a contracorriente es directamente proporcional al tiempo requerido para recorrer la distancia $d$ y el cubo de la velocidad. ¿Qué velocidad $v$ minimiza la energía empleada en nadar esta distancia?
#
# Minimizar la energía $E \infty t \cdot v^3$ donde $ t = \frac{d}{ v - v_c}$
#
# Funcion energia
#
# $E(v) = k \cdot \frac{d}{v - v_{c}} \cdot v^{3}$
# (k es una  constante)
#
# Derivar e igualar a cero
#
# $\frac{dE}{dv} = kd \cdot \frac{3v^{2}(v - v_{c}) - v^{3}}{(v - v_{c})^{2}} = 0 \implies 3v^{2}(v - v_{c}) = v^{3}$
#
# simplificar
#
# $3(v - v_{c}) = v \implies v = \frac{3v_{c}}{2}$
#
# Verificar mínimo: Segunda derivada positiva para  $v > v_c $}
#
# La velocidad que minimiza la energía es $\frac{3v_c}{2}$
#
# 3. Un pasillo de 6 pies de ancho da vuelta en ángulo recto. ¿Cuál es
# la longitud de la varilla delgada más larga que puede transportarse alrededor de la esquina, suponiendo que la varilla no puede doblarse?
#
# Maximizar la longitud L de la varilla que gira en un pasillo de 6 pies y otro de ancho w
#
# Modelar geometría: La varilla forma un triángulo con las paredes
#
# $L = \frac{6}{\sin \theta} + \frac{6}{\cos \theta}$
#
# Derivar e igualar a cero
#
# $\frac{dL}{d\theta} = -6 \cot \theta \csc \theta + 6 \tan \theta \sec \theta = 0 \implies \tan^3 \theta = 1 \implies \theta = \frac{\pi}{4}$
#
# Calcular L
#
# $L = \frac{6}{\sin\left(\frac{\pi}{4}\right)} + \frac{6}{\cos\left(\frac{\pi}{4}\right)} = 6\sqrt{2} + 6\sqrt{2} = 12\sqrt{2} \, \text{pies}$
#
# La longitud máxima es $12 \sqrt{2}$
#
# 4. Un objeto que se arroja desde el borde de un acantilado de 100 pies, sigue la trayectoria dada por  $ h=\frac{-x^2}{100}+x+100$.
# Un observador se encuentra parado a 2 pies del fondo del acantilado.
# (a) Encuentre la posición del objeto cuando está más cerca del observador.
# (b) Encuentre la posición del objeto cuando está más lejos del observador.
#
# trayectoria: $h(x) = -\frac{x^2}{100} + x + 100$
#
#
# Distancia al observador:  observador en (0,2)
#
# $D(x) = \sqrt{x^{2} + \left(h(x) - 2\right)^{2}}$
#
# Minimizar $D(x)$
#
# $D^2(x) = x^2 + \left(-\frac{x^2}{100} + x + 98\right)^2$
#
# $x ≈ 50 $pies
#
# Maximizar distancia: Evaluar en extremos del dominio $ x = 0 h(x) = 0 $
#
# $h(x) = 0, \text{ resolver } -\frac{x^2}{100} + x + 100 = 0 $
#
# $ x \approx 61.8 \, \text{pies.}$
#
# Entonces:
#
# a) Más cercano: x ≈ 50 pies
#
# b) Más lejano: x ≈ 61,8 pies

# %% [markdown]
# <font color="ADFF2F">EJERCICIOS QUE REQUIEREN DE CODIGO</font>
#
# <font color="ADFF2F">I.</font> For each of the following equations, use a graph to obtain initial guesses for solutions and then apply Newton’s method to locate the solutions within 0.0001. use code
#
# 1. $x^5-6x^3+2x=2$
#
# 2. $senx=x^2$
#
# 3. $cost=t^2$
#
# 4. $2senx=\sqrt{x+1}$
#
# <font color="ADFF2F">II.</font>  Use Newton’s method to approximate $\sqrt[3]{2}$ with an error less than 0.00005.  Use $x^n-k=0$

# %%
#PUNTO 1
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 400)
y = x**5 - 6*x**3 + 2*x - 2

plt.plot(x, y)
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.grid(True)
plt.show()

# %% [markdown]
# Como se muestra en la grafica, hay 3 puntos de corte, los cuales no son numeros enteros y su factorizazion sería mjuy complicada, para ello usamos el metodo de nweton pars aproximar las raices de la funciom, vamos a sacar los intervalos de losp untos de corte
# -3,-2
# -1,0
# 2,3

# %%
def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

# Ejemplo de uso:
f=lambda x: x**5 - 6*x**3 + 2*x -2
g=lambda x: 5*x**4 - 18*x**2 + 2
x0 = -3
tol = 1e-5
maxiter = 10000
root = newton_raphson(f, g, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: -2.340731830225308

# %%
#PUNTO 2
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 400)
y = np.sin(x) - x**2

plt.plot(x, y)
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.grid(True)
plt.show()

# %%
def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

# Ejemplo de uso:
f=lambda x: np.sin(x) - x**2
g=lambda x: np.cos(x) - 2*x
x0 = 0.5
tol = 1e-5
maxiter = 10000
root = newton_raphson(f, g, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: 0.8767274201470954

# %%
#PUNTO 3
import matplotlib.pyplot as plt
import numpy as np

t = np.linspace(-3, 3, 400)
y = np.cos(t) - t**2

plt.plot(x, y)
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.grid(True)
plt.show()

# %%
def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

# Ejemplo de uso:
f=lambda x: np.cos(x) - x**2
g=lambda x: -np.sin(x) - 2*x
x0 = -1
tol = 1e-5
maxiter = 10000
root = newton_raphson(f, g, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: -0.8241323190509289

# %%
#PUNTO 4
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 50, 400)
y = 2 * np.sin(x) - np.sqrt(x + 1)

plt.plot(x, y)
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-7-e39cbf705e07>:6: RuntimeWarning: invalid value encountered in sqrt
#   y = 2 * np.sin(x) - np.sqrt(x + 1)

# %%
def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

# Ejemplo de uso:
f=lambda x:  2 * np.sin(x) - np.sqrt(x + 1)
g=lambda x: 2 * np.cos(x) - (x + 1)**1/2
x0 = 2
tol = 1e-5
maxiter = 10000
root = newton_raphson(f, g, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: 2.0730360235963206

# %%
#EJERCICIO II
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3, 3, 400)
y = x**3 - 2

plt.plot(x, y)
plt.axhline(0, color='gray')
plt.axvline(0, color='gray')
plt.grid(True)
plt.show()

# %%
def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x

        fp = fprime(x)
        if fp == 0:
            print('Error la derivada es cero')
            break
        x = x - fx / fp
    return x

# Ejemplo de uso:
f=lambda x: x**3 - 2
g=lambda x: 3 * x**2
x0 = 1.2
tol = 1e-5
maxiter = 10000
root = newton_raphson(f, g, x0, tol, maxiter)
print(f"La raíz de la función es: {root}")
# Out:
# La raíz de la función es: 1.2599210499374096

# %% [markdown]
# <font color="ADFF2F">EJERCICIOS COSTE MARGINAL</font>
#
# En la fabricación y venta de x unidades de cierto bien de consumo, las funciones de precio $P$ y de costo $C$ (en dólares) están dadas por:
#
# $$P(x) = 5.00 - 0.002x$$
#
# $$C(x)=3.00 + 1.10x$$
#
# Encuentre las expresiones para el ingreso, el costo y la utilidad marginales. Determine el nivel de producción que producirá la máxima utilidad total.Explique con claridad cada proceso

# %% [markdown]
# Ingreso total  R(x) Dinero obtenido por vender x unidades.
#
# $\begin{align*}
# R(x) &= P(x) \cdot x \\
#      &= (5.00 - 0.002x)x \\
#      &= 5.00x - 0.002x^2
# \end{align*}$
#
# Costo Total C(x) Dinero gastado en producir x unidades.
#
# $C(x) = 3.00 + 1.10x \quad (\text{Dado})$
#
# Utilidad Total II  (x) Beneficio obtenido.
#
# $\begin{align*}
# \Pi(x) &= R(x) - C(x) \\
#        &= (5.00x - 0.002x^2) - (3.00 + 1.10x) \\
#        &= -0.002x^2 + 3.90x - 3.00
# \end{align*}$
#
#
# simplificar
#
# $\Pi(x) = -0.002x^2 + 3.90x - 3.00$
#
#
# marginales - derivadas de las funciones totales respecto a x
#
# Ingreso Marginal (R ′(x)): Cambio en el ingreso al producir una unidad adicional.
#
# $R'(x) = \frac{d}{dx}(5.00x - 0.002x^2) = 5.00 - 0.004x$
#
# Costo Marginal (C ′(x)): Cambio en el costo al producir una unidad adicional.
#
# $C'(x) = \frac{d}{dx}(3.00 + 1.10x) = 1.10$
#
# Utilidad Marginal (II ′(x)): Cambio en la utilidad al producir una unidad adicional.
#
# $\begin{align*}
# \Pi'(x) &= R'(x) - C'(x) \\
#         &= (5.00 - 0.004x) - 1.10 \\
#         &= 3.90 - 0.004x
# \end{align*}$
#
#
# Maximizar la utilidad total: encontrar el nivel de producción (x) que maximiza la utilidad
#
# Derivar la utilidad total e igualar a cero:
#
# $\Pi'(x) = 3.90 - 0.004x = 0$
#
# Resolver para X:
#
# $0.004x = 3.90 \implies x = \frac{3.90}{0.004} = 975 \text{ unidades}$
#
# Verificar que es un máximo:
#
# $\Pi''(x) = -0.004 \quad (\text{Negativa, por lo tanto es un máximo})$
#
# ENTONCES:
#
# $R'(x) = 5.00 - 0.004x$
#
# $C'(x) = 1.10 $
#
# $\Pi'(x) = 3.90 - 0.004x$
#
# x = = 975 unidades
#
# Sustituyendo x=975 en II(x): $Π(975)=−0.002(975)^2 +3.90(975)−3.00= $1899.75$

# %% [markdown]
# <font color="ADFF2F">EJERCICIOS GRAFICAS</font>

# %% [markdown]
# <font color="ADFF2F">I. </font>Haga un análisis como el sugerido en el resumen anterior y después elabore un bosquejo de la gráfica
#
#  <font color="ADFF2F">1. $f(x)=\frac{x}{x+1}$ </font>
#
# Paso 1. Analisis antes de cálculo
#
# $x  \neq -1  \rightarrow -1+1 = 0 $
#
# Dominino: $(-∞, -1) U (-1, ∞)$
#
# $y = \frac{x}{x+1}$
#
# $y (x +1)= x$
#
# $yx + y= x$
#
# $-y = yx - x$
#
# $-y = x ( y - 1)$
#
# $\frac{-y}{y -1} = x$ $x \neq 1$
#
# Rango (-∞, 1) U (-1, ∞)
#
# Rango: $ y \neq  1$
#
# $f (-x) = f(x) -> f(-c) = \frac{-x}{-x+1}$
#
# $\frac{-x}{x-1} \neq \frac{-x}{x+1}$ no es par (eje y)
#
# $f (-x) = -f(x) -> f(x) = \frac{x}{x+1}$
#
# $\frac{-x}{-x+1} \neq \frac{-x}{x+1}$ no es impar (origen)
#
# Simetria: No hay simetria en ninguno de los ejes
#
# Intersecciones: tiene una sola intersección con ambos ejes al tiempo
#
# eje x: $f_ x = 0 \rightarrow x = 0$
#
# eje y: $f_ 0 = 0 $
#
# Paso 2. Análisis con cálculo
#
# Primera Derivada, Puntos criticos:
#
# $f'(x) = \frac{(1)(x+1) - x(1)}{(x+1)^2} = \frac{1}{(x+1)^2} > 0 \quad (\text{siempre creciente}).\$
#
# Segunda Derivada, Punto de inflexión:
#
# $f''(x) = \frac{-2}{(x+1)^{3}} $
#
# Asíntotas: $\frac{x}{x+1}$
#
# Vertical: $x = -1$
# Horizontal : $y= \frac{1}{1} = 1$
#
# Intersecciones
#
# Eje y: $f(0) = \frac{0}{0+1} = 0$
#
# Eje x: $f(x) = 0, 0 = \frac{x}{x-1}, 0 (x -1) = x, 0 = x $
#
# (0,0) tiene una sola intersección con ambos ejes al tiempo
#
# <font color="ADFF2F"> 2. $g(x)=\frac{|x|+x}{2}(3x+2)$</font>
#
# Dominio: R, No hay raices de denominadores ni logaritmos:
#
# $ Si x  \geq 0: |x| + x = 2x  \rightarrow g(x) = x(3x +2) = 3x^2 + 2x $
#
# $Si x  < 0: |x| + x = 0 \rightarrow g(x) = 0 $
#
# Rango: [0, ∞ )
#
# $x  \geq 0$
# f(x) = 0
#
# Parábola $ 3x^2 +2x $ (abre hacia arriba, vértice en $x = -\frac{b}{2a} = -\frac{1}{3} $ pero $ x \geq 0 $ fuera del dominio
#
# intersección en $(0,0) eje y: f(0) = 3(0)^2 + 2(0) = 0, eje x: f(x) = 0 $
#
# Puntos criticos:
#
# $f(x) = gx +2 $
#
# $6x +2 = 0 $
#
# $x =- \frac{1}{3}$
#
# $x < 0 = 0$ es constante
#
# Decrece: $(-∞,0) $, Crece: $(0,+∞) $
#
# Punto de inflexión:
#
# $f''(x) = 6, 6 = 0$
#
#
# $f''(5) = 6$
#
# $f''(7) = 6$
#
# concava: $(-∞, ∞)$
# convexa: No hay
#
# Asíntotas
#
# Verticales: tiende a infinito, No hay Horizontales: $lim_x \rightarrow ∞ f(x) = $constante, No hay valor constante
#
# <font color="ADFF2F"> 3. $f(x)=\frac{x^2}{x^2-1}$ </font>
#
# Dominio y Rango
#
# Dominio:$R -{-1,1}$
# Rango: $(-∞,0]U(1,∞)
#
# Simetria:
#
# par (eje y): $f(x) = f(-x) → \frac{x^2}{-x^2-1}  = \frac{x^2}{x^2-1}$
#
# impar(origen): $f(-x) = -f(x) → -( \frac{x^2}{x^2-1} ) = \frac{x^2}{x^2-1}$
#
# Puntos criticos: $f'(x) = \frac{2x(x^2-1)-x^2(2x)}{(x^2-1)^2} = \frac{-2x}{(x^2-1)^2} = 0 → -2x = 0 → x = 0 $
#
# Crece: $(-∞,0)$
# Decrece: $(0, ∞)$
#
# Es un maximo
#
#
# Puntos de inflexión: $f"(x)= \frac{-2(x^2-1)^2)-(-2x)(4x/x^2-1))}{(x^2-1)^4} = \frac{6x^2+2}{(x^2-1)^3}$
#
# $\frac{6x^2+2}{(x^2-1)^3} = 0 → 6x^2 = -2 → x^2 = \frac{-2}{6} → \sqrt{\frac{-1}{3}} → -1^\frac{3}{2} → -1 $
#
# concava: $(-∞, -1)$ convexa: $(-1, +∞)$
#
# Asintotas
#
# Vertical: $x^2-1  \neq 0 $, $x^2-1  = 0 $
#
#
#
# $x= 1 y = -1$
#
# Horizontal: $lim_x\rightarrow ∞$ $f(x) = \frac{1}{1-0} = 1$
#
# asintota vertical en y = 1
#
#
#  <font color="ADFF2F">4.$h(x)=\frac{5.235x^3-1.245}{7.126x-3.141}$  </font>
#
#  Dominio y Rango
#
# $7.126x - 3.141 = 0$
#
# $x = \frac{3.141}{7.126}$
#
# $x = 0.441$
#
# Dominio: $(-∞,0.441) U (0441, ∞)$
#
# Rango: Polinimonio grado 3 $\rightarrow$ Numerador polinomio grado 1 $\rightarrow$ denominador tiende a -∞ o +∞ depende del signo
#
# Rango: (-∞, ∞)
#
# Simetria:
#
# Par (Eje y): f(x) = f(-x) → $\frac{-5.235x^3-1.245}{-7.126x-3.141} $
#
# $\frac{5.235x^3-1.245}{7.126x-3.141} \neq \frac{-5.235x^3-1.245}{-7.126x-3.141} $
#
# Impar(origen)
#
# $f(x) = -f(x) → -(\frac{5.235x^3-1.245}{7.126x-3.141}) $
#
# $ \frac{-5.235x^3-1.245}{-7.126x-3.141} \neq \frac{-5.235x^3+1.245}{7.126x-3.141} $
#
# Intersecciones
#
# Eje y: $f(0) = \frac{5.235(0)^3-1.245}{7.126(0)-3.141} = 0.3963$
#
# $(0,0.3963)$
#
# Eje x: $5.235x^3 -1.245 = 0 $
#
# $ x^3 = \frac{1.245}{5.235} $
#
# $ x = 0.620 $
#
# $7.126 (0.620) - 3.141 = 4.418 - 3.141 = 1.277 \neq 0 $
#
# Interseccion en eje x: (0.620, 0 )
#
# Puntos crititcos: $f"(x) = \frac{15.705x^2(7.216x-3.141)-(5.235x^3-1.245)(7.216)}{7.126x-3.141)^2}$
#
# expansiones
#
# $15.705x^2 (7.126x - 3.141)-7.126(5.235x^3 - 1.242)= 0 $
#
# $15.705x^2 (7.126x - 3.141) = 15.705x^2 - 7.126x- 15.705x^2 \cdot 3.141 = 111.979x^3 - 49.332x^2$
#
# $7.126(5.235x^3 - 1.245) = 37.287x^3 - 8.872$
#
# sustitución
#
# $(11.979x^3 - 49.332x^2) - (37.287x^3 - 8.872) = 0 $
#
# $74.692x^3 - 49.332x^2+ 8.872 = 0 $
#
# x = -0.344
#
# decrece: ( -∞, 0.344)
# creece: (0.344 , ∞)
# 0.344 es un minimo
#
# Puntos de inflexión:
#
# $f"(x) = \frac{(224.076x^2-98.664x)(7.126x - 3.141)^2(74.692x^3 - 49.332x^2 + 8.872)(2\cdot 7.126(7.126x-3.141))}{(7.126x - 3.141)^4}$
#
# x = 0.975
#
# f"(-1)=-23.63
# f"(1)=16.08
#
# convexa: (-∞, 0.975)
# concava: (0.975, ∞)
#
# Asintotas
#
# Vertical: 7.126x - 3.141 = 0
#
# $x = \frac{3.141}{7.126} = 0.441$
#
# horizontal:
#
# grado 1 y 3 → el grado del numerador es mayor que el de denominador, No hay asintota

# %% [markdown]
# ![{E6D456A2-3E40-4A9B-A55A-047C90F6D4B6}.png](data:image/png;base64,...)

# %% [markdown]
# ![{1B5E6F9F-8D2C-416B-9CD3-D02AD434F5BE}.png](data:image/png;base64,...)

# %% [markdown]
# ![{22A414D9-B210-4C04-934D-DEAF60832D06}.png](data:image/png;base64,...)

# %% [markdown]
# ![{EC1FEA64-E818-41CF-83FD-3AF4A220937A}.png](data:image/png;base64,...)

# %% [markdown]
# <font color="ADFF2F">II. </font>Trace el Bosquejo de una grafica que cumpla las siguientes condiciones:
#
#  <font color="ADFF2F">1. </font>$f$ es continua
#
#  <font color="ADFF2F">2. </font>$f$ es par
#
#  <font color="ADFF2F">3. </font>$f(0)=0$, $f(1)=2$
#
#  <font color="ADFF2F">4. </font>$f'(x)>0$ para $x>0$
#
#  <font color="ADFF2F">5. </font>$f''(x)>0$, para $x>0$

# %% [markdown]
# ![{2D521762-C273-47CA-8C31-61DECF5629E8}.png](data:image/png;base64,...)

# %% [markdown]
# <font color="ADFF2F">III. </font>Trace el Bosquejo de una grafica que cumpla las siguientes condiciones:
#
# <font color="ADFF2F">a.</font> $f$ es continua en todas partes
#
# <font color="ADFF2F">b.</font> $f(2)=-3$ y $f(6)=1$
#
# <font color="ADFF2F">c.</font> $f'(2)=0$ para $x\neq 2$
#
# <font color="ADFF2F">d. </font>$f'(6)=3$
#
# <font color="ADFF2F">e. </font>$f''(6)=0$; $f''(x)>0$ Para $2<x<6$
#
# <font color="ADFF2F">f. </font>$f''(x)<0$ Para $x>6$

# %% [markdown]
# ![{811BD0BA-F73B-4448-A448-0E8817B1608B}.png](data:image/png;base64,...)
